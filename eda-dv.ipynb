# %% [markdown]
# ## EDA and DV Exercise
#
# In this exercise, you’ll explore a subset of the Craigslist car data. The goal is to understand the data: its structure, quality, and some patterns.
#
# We’ll move step by step:
# * Load and inspect the dataset
# * Summarize key columns
# * Visualize distributions
# * Explore relationships between variables

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Data Structure

# %%
# This will be different on your machine. You always have the option to 
# to make another copy in the folder of this repository.
listings = pd.read_csv("../631-eda-data-viz/car_listings.csv")

# Inspect structure using shape, head, info, dtypes
# Out:
# (266817, 24)
# url                   object
# location              object
# post_id                int64
# time_posted           object
# name                  object
# make                  object
# model                 object
# year                 float64
# odometer             float64
# title                 object
# paint                 object
# drive                 object
# cylinders             object
# fuel                  object
# type                  object
# transmission          object
# condition             object
# vin                   object
# price                float64
# posting_body_text     object
# title_text            object
# num_images           float64
# latitude             float64
# longitude            float64
# dtype: object
#                                                  url location     post_id  \
# 0  https://fargo.craigslist.org/cto/d/west-fargo-...    fargo  7787882335
# 1  https://chicago.craigslist.org/nwc/cto/d/des-p...  chicago  7789338453
# 2  https://chicago.craigslist.org/nch/cto/d/evans...  chicago  7789384937
# 3  https://chicago.craigslist.org/sox/cto/d/chica...  chicago  7789321782
# 4  https://chicago.craigslist.org/nwi/cto/d/scher...  chicago  7789402919
#
#                  time_posted                   name       make  \
# 0  2024-09-25 09:35:39+00:00   chevy equinox lt awd  chevrolet
# 1  2024-09-30 12:25:28+00:00           ford transit       ford
# 2  2024-09-30 14:33:58+00:00   ford escape titanium       ford
# 3  2024-09-30 11:42:21+00:00    nissan altima 2.5 s     nissan
# 4  2024-09-30 15:25:31+00:00  honda odyssey touring      honda
#
#              model    year  odometer  title  ...     type transmission  \
# 0          equinox  2013.0  160000.0  clean  ...      SUV    automatic
# 1  transit 250 van  2019.0   93000.0  clean  ...      van    automatic
# 2           escape  2014.0  122000.0  clean  ...      SUV    automatic
# 3           altima  2015.0  145000.0  clean  ...    sedan    automatic
# 4          odyssey  2007.0  230000.0  clean  ...  minivan    automatic
#
#    condition  vin    price                                  posting_body_text  \
# 0        NaN  NaN   6000.0  \n\nQR Code Link to This Post\n\n\n14 Equinox ...
# 1       good  NaN  21900.0  \n\nQR Code Link to This Post\n\n\n2019 Ford C...
# 2  excellent  NaN   6250.0  \n\nQR Code Link to This Post\n\n\n2014 Ford E...
# 3  excellent  NaN   5200.0  \n\nQR Code Link to This Post\n\n\nHeres is my...
# 4  excellent  NaN   3500.0  \n\nQR Code Link to This Post\n\n\nVery Nice V...
#
#                                           title_text num_images   latitude  \
# 0                                   14 Chevy Equinox       11.0  46.890700
# 1                          2019 FORD TRANSIT 250 VAN       14.0  42.023580
# 2  2014 Ford Escape (Excellent condition) Titaniu...       12.0  42.052098
# 3  2015 Nissan Altima S, 145k, *Remote Start*, 4 ...       11.0  41.781400
# 4                         2007 Honda Odyssey Touring       10.0  41.492200
#
#    longitude
# 0 -96.925800
# 1 -87.902577
# 2 -87.686005
# 3 -87.770500
# 4 -87.460500
#
# [5 rows x 24 columns]

# %%
# Basic summary: to_string is an easy way to see everything
print(listings.describe(include="all").to_string())
# Out:
#                                                                                                 url location       post_id                time_posted        name    make   model           year      odometer   title   paint   drive    cylinders    fuel    type transmission condition                vin          price                                                                                                                                                                                                                                                                                                                                                                                                                                        posting_body_text    title_text     num_images       latitude      longitude
# count                                                                                        266817   266817  2.668170e+05                     263017      262666  257869  243707  262668.000000  2.626320e+05  262670  193660  198520       207353  262668  218612       262671    219961              36977  255654.000000                                                                                                                                                                                                                                                                                                                                                                                                                                                   263017        263017  255956.000000  255742.000000  255742.000000
# unique                                                                                       258147       12           NaN                     246459       53785      61    1041            NaN           NaN       6      12       3            8       5      14            3         6              24208            NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                   219054        145260            NaN            NaN            NaN
# top     https://stlouis.craigslist.org/cto/d/cedar-hill-2001-chevrolet-tahoe-lt-4x4/7758235930.html  chicago           NaN  2024-06-22 10:02:10+00:00  ford f-150    ford    f150            NaN           NaN   clean   white     4wd  6 cylinders     gas     SUV    automatic      good  KNDJT2A60C7359211            NaN  \n\nQR Code Link to This Post\n\n\nwe are buying cars, trucks, vans, etc\nRUNNING OR NOT \nfender bender, mechanical issues?\nbeen in accident, taking space at the driveway?\nits taking space at your back yard?\nwe are offering from $500.00 and up depending the condition\nand the year\nWE ARE BUYING THEM ALL\n$$$$ CASH ON THE SPOT SAME DAY $$$\nALSO FREE TOWING\ncall or text to come get it now\nshow contact info\n\nthanks for looking\n  Toyota Camry            NaN            NaN            NaN
# freq                                                                                             25    85150           NaN                         25        2816   41784    7934            NaN           NaN  244933   40318   95285        79364  241781   67171       243190     91164                 83            NaN                                                                                                                                                                                                                                                                                                                                                                                                                                                       55           151            NaN            NaN            NaN
# mean                                                                                            NaN      NaN  7.769245e+09                        NaN         NaN     NaN     NaN    2009.254321  1.524287e+05     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN    9620.251469                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN      11.302009      42.393583     -90.338377
# std                                                                                             NaN      NaN  6.726187e+07                        NaN         NaN     NaN     NaN       6.304723  1.656137e+05     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN   10345.793452                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN       5.967262       3.021849       5.321630
# min                                                                                             NaN      NaN  7.525961e+09                        NaN         NaN     NaN     NaN    1990.000000  0.000000e+00     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN     500.000000                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN       1.000000     -72.895538    -155.901311
# 25%                                                                                             NaN      NaN  7.718964e+09                        NaN         NaN     NaN     NaN    2005.000000  1.000000e+05     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN    3671.250000                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN       7.000000      41.602800     -93.303637
# 50%                                                                                             NaN      NaN  7.772657e+09                        NaN         NaN     NaN     NaN    2010.000000  1.427960e+05     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN    6000.000000                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN      10.000000      42.113900     -89.452800
# 75%                                                                                             NaN      NaN  7.826912e+09                        NaN         NaN     NaN     NaN    2014.000000  1.850000e+05     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN   11500.000000                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN      15.000000      44.674900     -87.929764
# max                                                                                             NaN      NaN  7.878823e+09                        NaN         NaN     NaN     NaN    2023.000000  1.000000e+07     NaN     NaN     NaN          NaN     NaN     NaN          NaN       NaN                NaN  100000.000000                                                                                                                                                                                                                                                                                                                                                                                                                                                      NaN           NaN      24.000000      76.785337       0.000000

# %%
# Check missingness (again)
# Out:
# vin                  0.861414
# paint                0.274184
# drive                0.255969
# cylinders            0.222864
# type                 0.180667
# condition            0.175611
# model                0.086614
# price                0.041838
# latitude             0.041508
# longitude            0.041508
# num_images           0.040706
# make                 0.033536
# odometer             0.015685
# name                 0.015557
# fuel                 0.015550
# year                 0.015550
# title                0.015542
# transmission         0.015539
# time_posted          0.014242
# posting_body_text    0.014242
# title_text           0.014242
# location             0.000000
# post_id              0.000000
# url                  0.000000
# dtype: float64

# %%
# Let's make things run faster by cutting down to just Minneapolis
listings = listings.query("location == 'minneapolis'")

# %% [markdown]
# ### Summary Statistics
#
# Play around with some summary statistics in the code cell below.
#
# ### Question
#
# Which of the main numeric columns shows the biggest difference between the mean and median? What does that say about that data?

# %%
# Your code here
# Out:
# For year the difference is -0.66
# The relative difference is -0.00
# --------------------
# For odometer the difference is 4,048.41
# The relative difference is 0.03
# --------------------
# For price the difference is 3,455.25
# The relative difference is 0.35
# --------------------

# %% [markdown]
# ### Bonus Question
#
# If you're ahead, feel free to take a crack at comparing the IQR to the width of two standard deviations for these columns.

# %%
# Out:
#               price       odometer       year
# iqr     8550.000000   91542.000000   9.000000
# std_2  21177.162481  322409.274858  12.517029

# %% [markdown]
# ### Exploring Distributions
#
# Make histograms of price, odometer, and year for F-150s. Once you've made the basic plots, add some filtering to restrict the data to where most of the listings are.

# %%
f150s = 0 # cut down listings here

# %%
# start histograms here
# Out:
# (array([146., 157., 137., 140., 116., 112.,  81.,  87.,  82.,  41.,  43.,
#          35.,  32.,  49.,  26.,  20.,  26.,  19.,  23.,  11.,  16.,  17.,
#          10.,  20.,   8.,  11.,  12.,   7.,   8.,  11.,   4.,   6.,   3.,
#           3.,   8.,   5.,   5.,   3.,   7.,   3.,   2.,   1.,   7.,   1.,
#           1.,   5.,   2.,   2.,   1.,   4.]),
#  array([ 2000.  ,  2959.98,  3919.96,  4879.94,  5839.92,  6799.9 ,
#          7759.88,  8719.86,  9679.84, 10639.82, 11599.8 , 12559.78,
#         13519.76, 14479.74, 15439.72, 16399.7 , 17359.68, 18319.66,
#         19279.64, 20239.62, 21199.6 , 22159.58, 23119.56, 24079.54,
#         25039.52, 25999.5 , 26959.48, 27919.46, 28879.44, 29839.42,
#         30799.4 , 31759.38, 32719.36, 33679.34, 34639.32, 35599.3 ,
#         36559.28, 37519.26, 38479.24, 39439.22, 40399.2 , 41359.18,
#         42319.16, 43279.14, 44239.12, 45199.1 , 46159.08, 47119.06,
#         48079.04, 49039.02, 49999.  ]),
#  <BarContainer object of 50 artists>)

# %% [markdown]
# ### Exploring Relationships
#
# In this section, build some scatterplots of price vs year and price vs odometer for the F150s. I'm also going to include code to make a scatterplot of year vs model for some of the most popular models.

# %%
# scatterplot code here

# %% [markdown]
# Making a **mosaicplot** is non-trivial, but it's a cool trick to know.

# %%
import matplotlib.patches as patches

def mosaic_plot(data, x_var, y_var, figsize=(12, 8)):
    ct = pd.crosstab(data[y_var], data[x_var])
    col_totals = ct.sum(axis=0)
    col_props = col_totals / col_totals.sum()
    ct_prop = ct.div(col_totals, axis=1).fillna(0)
    
    fig, ax = plt.subplots(figsize=figsize)
    colors = plt.cm.Set3(np.linspace(0, 1, len(ct.index)))
    
    x_start = 0
    for col_idx, col in enumerate(ct.columns):
        col_width = col_props[col]
        
        y_start = 0
        for row_idx, row in enumerate(ct.index):
            row_height = ct_prop.loc[row, col]
            
            if row_height > 0:
                rect = patches.Rectangle(
                    (x_start, y_start), col_width, row_height,
                    facecolor=colors[row_idx], 
                    edgecolor='white', 
                    linewidth=1.5,
                    alpha=0.8
                )
                ax.add_patch(rect)
                y_start += row_height
        
        # Only show column labels, no individual cell counts
        ax.text(x_start + col_width/2, -0.03, 
               f'{col}\n({col_totals[col]})', 
               ha='center', va='top', fontsize=9, fontweight='bold')
        
        x_start += col_width
    
    # Clean formatting
    ax.set_xlim(0, 1)
    ax.set_ylim(-0.08, 1)
    ax.set_xlabel(x_var, fontsize=12, fontweight='bold')
    ax.set_ylabel(y_var, fontsize=12, fontweight='bold')
    ax.set_title(f'Mosaic Plot: {y_var} by {x_var}', fontsize=14, fontweight='bold')
    ax.set_xticks([])
    ax.set_yticks([])
    
    # Remove spines
    for spine in ax.spines.values():
        spine.set_visible(False)
    
    # Legend with row totals
    row_totals = ct.sum(axis=1)
    legend_elements = [
        patches.Patch(facecolor=colors[i], label=f'{row} ({row_totals[row]})', alpha=0.8) 
        for i, row in enumerate(ct.index)
    ]
    ax.legend(handles=legend_elements, loc='center left', bbox_to_anchor=(1, 0.5))
    
    plt.tight_layout()
    return fig, ax

# %%
models_for_plot = ["f150","camry","silverado","accord","impala","civic","rav4"]
plot_data = listings.loc[listings["model"].isin(models_for_plot)]
plot_data = plot_data.loc[plot_data["year"].between(2005,2015)]

# %%
# Nice to have the model counts sorted
model_counts = plot_data["model"].value_counts()
sorted_models = model_counts.index.tolist()  # This gives you models in descending order

plot_data["model"] = pd.Categorical(plot_data["model"], categories=sorted_models, ordered=True)

# %%
fig, ax = mosaic_plot(plot_data,"model","year")
plt.show()

# %% [markdown]
# ### Question
#
# What patterns can you find in the mosaic plot? (I notice some interesting annual behavior by model.)
